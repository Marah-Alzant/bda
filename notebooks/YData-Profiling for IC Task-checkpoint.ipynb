# %% [markdown]
# <b>Description:</b>
# -

# %% [markdown]
# ### Import Python libraries and user-defined modules

# %%
#from dotenv import load_dotenv
import pandas as pd
import ydata_profiling
from ydata_profiling import ProfileReport
# Out:
# C:\Users\97259\AppData\Local\Temp\ipykernel_40132\3064544796.py:3: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   import ydata_profiling

# %%
#import prep.preprocessing as prep

# %%
pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\97259\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2026.5.9-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\97259\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.68.2)
# Requirement already satisfied: colorama in c:\users\97259\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached regex-2026.5.9-cp313-cp313-win_amd64.whl (277 kB)
# Using cached click-8.4.1-py3-none-any.whl (116 kB)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.4.1 nltk-3.9.4 regex-2026.5.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: C:\Users\97259\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\97259\\Downloads\\WinPython64-3.13.13.0dot\\WPy64-313130\\notebooks\\DEV\\bda\\notebooks'

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\97259\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\97259\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\97259\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# ### Load variables from .env file

# %%
#load_dotenv()

XLSX_FILES_FOLDER = "../data/xlsx"
HTML_REPORTS_FOLDER = "../reports"

XLSX_FILES_FOLDER, HTML_REPORTS_FOLDER
# Out:
# ('../data/xlsx', '../reports')

# %% [markdown]
# ### Read the dataset and high-level EDA

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages (from openpyxl) (2.0.0)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)

# %%
# !pip install openpyxl --no-cache-dir --force-reinstall
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#   Attempting uninstall: et-xmlfile
#
#     Found existing installation: et_xmlfile 2.0.0
#
#     Uninstalling et_xmlfile-2.0.0:
#
#       Successfully uninstalled et_xmlfile-2.0.0
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#   Attempting uninstall: openpyxl
#    ---------------------------------------- 0/2 [et-xmlfile]
#     Found existing installation: openpyxl 3.1.5
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#     Uninstalling openpyxl-3.1.5:
#    -------------------- ------------------- 1/2 [openpyxl]
#       Successfully uninstalled openpyxl-3.1.5
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)

# %%
# !python -m pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages (from openpyxl) (2.0.0)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\Envs\bigdata\Lib\site-packages)

# %%
import openpyxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import openpyxl
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
#df = read_excel_files(XLSX_FILES_FOLDER, pattern, debug=True)
df= pd.read_excel(XLSX_FILES_FOLDER+"/image_metadata.xlsx", sheet_name="Sheet1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 2
#       1 #df = read_excel_files(XLSX_FILES_FOLDER, pattern, debug=True)
# ----> 2 df= pd.read_excel(XLSX_FILES_FOLDER+"/image_metadata.xlsx", sheet_name="Sheet1")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)    539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)    550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
import pandas as pd

# القراءة المباشرة بالمسار الكامل والصحيح للملف
df = pd.read_excel(r"C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\DEV\bda\data\xlsx\image_metadata.xlsx", sheet_name="Sheet1")

# عرض أول 5 أسطر للتأكد من نجاح القراءة
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 4
#       1 import pandas as pd
#       2
#       3 # القراءة المباشرة بالمسار الكامل والصحيح للملف
# ----> 4 df = pd.read_excel(r'C:\Users\97259\Downloads\WinPython64-3.13.13.0dot\WPy64-313130\notebooks\DEV\bda\data\xlsx\image_metadata.xlsx', sheet_name="Sheet1")
#       5
#       6 # عرض أول 5 أسطر للتأكد من نجاح القراءة
#       7 df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)    539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)    550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def preprocess(text):

    text = text.lower()

    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)

    tokens = text.split()

    tokens = [
        lemmatizer.lemmatize(w)
        for w in tokens
        if w not in stop_words and len(w) > 2
    ]

    return " ".join(tokens)

# %%
#df.shape ##(502, 9)
df["caption_clean"] = df["caption"].apply(preprocess)

# %%
df.head()
# Out:
#    project_id   category            image_id  \
# 0         212  Reflector     20180105_101214
# 1         212  Reflector     20180105_101224
# 2         212  Reflector     20180302_135657
# 3         212  Reflector     20180302_135706
# 4         212  Reflector  20180418-Vortest-1
#
#                                              caption  caption_ai  \
# 0  a large stainless steel disc with a milled sur...         NaN
# 1                          a rectangular steel plate         NaN
# 2  Housing of the beryllium reflector, clamped wi...         NaN
# 3  Housing of the beryllium reflector, clamped wi...         NaN
# 4  Mounted housing of the beryllium reflector on ...         NaN
#
#                                        caption_clean
# 0          large stainless steel disc milled surface
# 1                            rectangular steel plate
# 2  housing beryllium reflector clamped six black ...
# 3  housing beryllium reflector clamped six black ...
# 4  mounted housing beryllium reflector traversing...

# %%
col_to_drop = "caption_ai"
df_ic = None
if col_to_drop in df.columns:
    df_ic = df.drop(columns=[col_to_drop])
df_ic.head()
# Out:
#    project_id   category            image_id  \
# 0         212  Reflector     20180105_101214
# 1         212  Reflector     20180105_101224
# 2         212  Reflector     20180302_135657
# 3         212  Reflector     20180302_135706
# 4         212  Reflector  20180418-Vortest-1
#
#                                              caption  \
# 0  a large stainless steel disc with a milled sur...
# 1                          a rectangular steel plate
# 2  Housing of the beryllium reflector, clamped wi...
# 3  Housing of the beryllium reflector, clamped wi...
# 4  Mounted housing of the beryllium reflector on ...
#
#                                        caption_clean
# 0          large stainless steel disc milled surface
# 1                            rectangular steel plate
# 2  housing beryllium reflector clamped six black ...
# 3  housing beryllium reflector clamped six black ...
# 4  mounted housing beryllium reflector traversing...

# %%
#df_ic.info()

# %% [markdown]
# ### Generate Reports using YData/YData-SDK Profiling

# %%
import time

# %%
start = time.time()
title = "IC for Archive Projects-ITE"

#profile = ProfileReport(df_ic, title=f"{title}", minimal=False, correlations={"pearson": {"calculate": True}, "spearman": {"calculate": True}})
profile = ProfileReport(df_ic, title=f"{title}")

out_html = HTML_REPORTS_FOLDER + f"/{title}.html"
profile.to_file(out_html)

end = time.time()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.35it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
minutes = (end - start) / 60
print(f"Report generated in {minutes:.2f} minutes")
# Out:
# Report generated in 0.14 minutes
