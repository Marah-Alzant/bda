
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy_utils import database_exists, create_database

# %%
from local_settings import postgresql as settings

# %%
type(settings)
# Out:
# dict

# %%
settings.keys()
# Out:
# dict_keys(['pguser', 'pgpassword', 'pghost', 'pgport', 'pgdbname'])

# %%
settings['pguser']
# Out:
# 'postgres'

# %%
def get_engine(user, passwd, host, port, db):
    url = f"postgresql://{user}:{passwd}@{host}:{port}/{db}"
    
    if not database_exists(url):
        create_database(url)

    engine = create_engine(url, pool_size=50, echo=False)
    return engine

# %%
#It is better to put them in JSON file.
engine = get_engine(
    settings['pguser'],
    settings['pgpassword'],
    settings['pghost'],
    settings['pgport'],
    settings['pgdbname']
)

# %%
def get_engine_from_settings():
    keys = ['pguser', 'pgpassword', 'pghost', 'pgport', 'pgdbname']

    if not all(key in keys for key in settings.keys()):
        raise Exception('Bad config file')

    return get_engine(
        settings['pguser'],
        settings['pgpassword'],
        settings['pghost'],
        settings['pgport'],
        settings['pgdbname']
    )

# %% [markdown]
# ## Creting a DB connection using sqlalchemy engine

# %%
from sqlalchemy import text
import pandas as pd

# %% [markdown]
# ### Handle palin text

# %%
# This enables the automatic garbage collection,
with engine.connect() as connection:
    result = connection.execute(text("select name from users_tbl"))
    for row in result:
        print("Full Name:", row.name)
# Out:
# Full Name: Alice Johnson
# Full Name: Bob Smith
# Full Name: Charlie Brown

# %% [markdown]
# ### Handle it as pandas dataframe

# %%
#sql_query = "SELECT name,email FROM users_tbl"
sql_query = "SELECT * FROM users_tbl"
df = None
with engine.connect() as conn, conn.begin():
    df = pd.read_sql_query(sql_query, conn)

# %%
df.head()
# Out:
#    id           name                email      password_hash  \
# 0   1  Alice Johnson    alice@example.com  hashed_password_1
# 1   2      Bob Smith      bob@example.com  hashed_password_2
# 2   3  Charlie Brown  charlie@example.com  hashed_password_3
#
#                   created_at
# 0 2026-05-23 16:07:09.503927
# 1 2026-05-23 16:07:09.503927
# 2 2026-05-23 16:07:09.503927

# %% [markdown]
# ### Creating a session from engine using sqlalchemy

# %%
def get_session():
    engine = get_engine_from_settings()
    session = sessionmaker(bind=engine)()
    return session

# %%
session = get_session()

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\97259\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\97259\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\97259\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\97259\\AppData\\Local\\Programs\\Python\\Python313', '', 'C:\\Users\\97259\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages']
