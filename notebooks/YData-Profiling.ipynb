# %%
import data_profiling
from data_profiling import ProfileReport

# %%
import pandas as pd

# %%
import setuptools, sys; print(sys.executable); print(setuptools.__version__)
# Out:
# D:\Opera Downloads\WPy64-31330\notebooks\envs\bigdata\Scripts\python.exe
# 81.0.0

# %%
df = pd.read_csv("../data/trending-books.csv")

# %%
df.shape
# Out:
# (100, 8)

# %%
df.head()
# Out:
#    Rank                                         book title  book price  \
# 0     1                       Iron Flame (The Empyrean, 2)       18.42
# 1     2                                    The Woman in Me       20.93
# 2     3                                  My Name Is Barbra       31.50
# 3     4  Friends, Lovers, and the Big Terrible Thing: A...       23.99
# 4     5                              How to Catch a Turkey        5.65
#
#    rating            author  year of publication               genre  \
# 0     4.1    Rebecca Yarros                 2023     Fantasy Romance
# 1     4.5    Britney Spears                 2023              Memoir
# 2     4.5  Barbra Streisand                 2023       Autobiography
# 3     4.4     Matthew Perry                 2023              Memoir
# 4     4.8      Adam Wallace                 2018  Childrens, Fiction
#
#                                                  url
# 0  amazon.com/Iron-Flame-Empyrean-Rebecca-Yarros/...
# ...

# %%
profile = ProfileReport(df, title="Books Dataset Report-Kaggle")

# %%
#profile.to_widgets()

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.19.1&quot; name=generator&gt;&lt;meta content=https://github.com/Data-Centric-AI-Community/data-profiling name=url&gt;&lt;meta content=&quot;2026-06-10 07:16:54.432397&quot; name=date&gt;&lt;title&gt;Books Dataset Report-Kaggle&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
profile.to_file("../reports/Books_Report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
